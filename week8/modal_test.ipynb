# %%
import modal

app = modal.App("example-get-started")

@app.function()
def square(x):
    print("This code is running on a remote worker!")
    return x**2


@app.local_entrypoint()
def main():
    print("the square is", square.remote(42))

# %%
with app.run():
    main()
# Out:
# ---------------------------------------------------------------------------
# AuthError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 with app.run():
#       2     main()
#
# File /opt/anaconda3/envs/llms/lib/python3.11/contextlib.py:210, in _AsyncGeneratorContextManager.__aenter__(self)
#     208 del self.args, self.kwds, self.func
#     209 try:
# --> 210     return await anext(self.gen)
#     211 except StopAsyncIteration:
#     212     raise RuntimeError("generator didn't yield") from None
#
# File /opt/anaconda3/envs/llms/lib/python3.11/site-packages/modal/app.py:364, in _App.run(self, client, detach, interactive, environment_name)
#     323 """Context manager that runs an ephemeral app on Modal.
#     324
#     325 Use this as the main entry point for your Modal application. All calls
#    (...)    360
#     361 """
#     362 from .runner import _run_app  # Defer import of runner.py, which imports a lot from Rich
# --> 364 async with _run_app(
#     365     self, client=client, detach=detach, interactive=interactive, environment_name=environment_name
#     366 ):
#     367     yield self
#
# File /opt/anaconda3/envs/llms/lib/python3.11/contextlib.py:210, in _AsyncGeneratorContextManager.__aenter__(self)
#     208 del self.args, self.kwds, self.func
#     209 try:
# --> 210     return await anext(self.gen)
#     211 except StopAsyncIteration:
#     212     raise RuntimeError("generator didn't yield") from None
#
# File /opt/anaconda3/envs/llms/lib/python3.11/site-packages/modal/runner.py:291, in _run_app(app, client, detach, environment_name, interactive)
#     288         app.set_description(__main__.__name__)
#     290 if client is None:
# --> 291     client = await _Client.from_env()
#     293 app_state = api_pb2.APP_STATE_DETACHED if detach else api_pb2.APP_STATE_EPHEMERAL
#     295 output_mgr = _get_output_manager()
#
# File /opt/anaconda3/envs/llms/lib/python3.11/site-packages/modal/client.py:222, in _Client.from_env(cls, _override_config)
#     220     credentials = (token_id, token_secret)
#     221 else:
# --> 222     raise AuthError(
#     223         "Token missing. Could not authenticate client."
#     224         " If you have token credentials, see modal.com/docs/reference/modal.config for setup help."
#     225         " If you are a new user, register an account at modal.com, then run `modal token new`."
#     226     )
#     228 server_url = c["server_url"]
#     229 client = _Client(server_url, client_type, credentials)
#
# AuthError: Token missing. Could not authenticate client. If you have token credentials, see modal.com/docs/reference/modal.config for setup help. If you are a new user, register an account at modal.com, then run `modal token new`.

# %%
# !python3 -m modal setup
# Out:
# The web browser should have opened for you to authenticate and get an API token.
# If it didn't, please copy this URL into your web browser manually:
#
# ]8;id=521728;https://modal.com/token-flow/tf-aPPYHPpx7HfDjOsiOe8Pcf\https://modal.com/token-flow/tf-aPPYHPpx7HfDjOsiOe8Pcf]8;;\
#
# ⠋ Waiting for authentication in the web browser
# ⠧ Waiting for token flow to complete...omplete...
# Web authentication finished successfully!
# Token is connected to the ryansunmoon-info workspace.
# Verifying token against https://api.modal.com
# Token verified successfully!
# ⠋ Storing token
# Token written to /Users/ryansun/.modal.toml in profile ryansunmoon-info.
